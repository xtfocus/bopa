# %%
from fastbook import *
from fastai.vision.widgets import *
from PIL import Image

# %%
key = os.environ.get('AZURE_SEARCH_KEY', '73054b9ab75e462e81e11f32920fa489')

# %%
fruits = 'peach','orange','apple','banana'
path = Path('fruits')

# %%
if not path.exists():
    path.mkdir()
    for o in fruits:
        dest = (path/o)
        dest.mkdir(exist_ok=True)
        results = search_images_bing(key, f'{o} fruit')
        download_images(dest, urls=results.attrgot('contentUrl'))

# %%
# Double check
fns = get_image_files(path)
fns
# Out:
# (#549) [Path('fruits/apple/00000058.jpg'),Path('fruits/apple/00000049.jpg'),Path('fruits/apple/00000100.png'),Path('fruits/apple/00000106.JPG'),Path('fruits/apple/00000125.jpg'),Path('fruits/apple/00000078.jpg'),Path('fruits/apple/00000076.jpg'),Path('fruits/apple/00000089.jpg'),Path('fruits/apple/00000026.png'),Path('fruits/apple/00000010.jpg')...]

# %%
failed = verify_images(fns) # check docstring
failed # try openning these file in the browser yourself
# Out:
# (#0) []

# %%
# remove corrupted images
failed.map(Path.unlink)
# Out:
# (#8) [None,None,None,None,None,None,None,None]

# %%
def png_to_jpg(paths):
    paths = [i for i in paths if str(i).endswith('.png')]
    for img_path in paths:
        png = Image.open(img_path)
        png = png.convert('RGB')
        png.save(str(img_path)[:-3] + 'jpg', 'JPEG', quality=80)

# %%
png_to_jpg(fns)
# Out:
# /home/tung/.virtualenvs/cvpy/lib/python3.7/site-packages/PIL/Image.py:961: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "

# %%
fruits = DataBlock(
    # simply tells DataBlock that we have image as input and Category as label
    blocks=(ImageBlock, CategoryBlock), 
    # which function to retreive image filename
    get_items=get_image_files, 
    # train-val split
    splitter=RandomSplitter(valid_pct=0.2, seed=42),
    # label using the parent folder
    get_y=parent_label,
    # resize each image to 128x128
    item_tfms=RandomResizedCrop(128, min_scale=0.5),
    batch_tfms=aug_transforms(mult=2)
)

dls = fruits.dataloaders(path)
dls.train.show_batch(max_n=4, nrows=1, unique=True)

# %%
learn = cnn_learner(dls, resnet18, metrics=error_rate)
learn.fine_tune(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.102232</td>
#       <td>0.768271</td>
#       <td>0.241379</td>
#       <td>00:10</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.022403</td>
#       <td>0.582134</td>
#       <td>0.250000</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.901716</td>
#       <td>0.397840</td>
#       <td>0.155172</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.766234</td>
#       <td>0.405385</td>
#       <td>0.155172</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.689858</td>
#       <td>0.390703</td>
#       <td>0.146552</td>
#       <td>00:10</td>
#     </tr>
#   </tbody>
# </table>

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()

# %%
interp.plot_top_losses(12, nrows=3)

# %%
cleaner = ImageClassifierCleaner(learn)
cleaner
# Out:
# /home/tung/.virtualenvs/cvpy/lib/python3.7/site-packages/PIL/Image.py:961: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# VBox(children=(Dropdown(options=('apple', 'banana', 'orange', 'peach'), value='apple'), Dropdown(options=('Tra…

# %%
for idx in cleaner.delete(): cleaner.fns[idx].unlink()

# move images for which we've selected a different category
for idx,cat in cleaner.change():
    shutil.move(str(cleaner.fns[idx]), path/cat)

# %%
learn.export(fname='fruits.pkl')
learn_if = load_learner('fruits.pkl')
learn_if.predict('fruits/banana/00000003.jpeg')
# Out:
# ----------------------------------------------------------------------
# FileNotFoundError                    Traceback (most recent call last)
# <ipython-input-95-04bac3cdd868> in <module>
#       1 learn.export(fname='fruits.pkl')
#       2 learn_if = load_learner('fruits.pkl')
# ----> 3 learn_if.predict('fruits/banana/00000003.jpeg')
#
# ~/.virtualenvs/cvpy/lib/python3.7/site-packages/fastai/learner.py in predict(self, item, rm_type_tfms, with_input)
#     249     def predict(self, item, rm_type_tfms=None, with_input=False):
#     250         dl = self.dls.test_dl([item], rm_type_tfms=rm_type_tfms, num_workers=0)
# --> 251         inp,preds,_,dec_preds = self.get_preds(dl=dl, with_input=True, with_decoded=True)
#     252         i = getattr(self.dls, 'n_inp', -1)
#     253         inp = (inp,) if i==1 else tuplify(inp)
#
# ~/.virtualenvs/cvpy/lib/python3.7/site-packages/fastai/learner.py in get_preds(self, ds_idx, dl, with_input, with_decoded, with_loss, act, inner, reorder, cbs, **kwargs)
#     236         if with_loss: ctx_mgrs.append(self.loss_not_reduced())
#     237         with ContextManagers(ctx_mgrs):
# --> 238             self._do_epoch_validate(dl=dl)
#     239             if act is None: act = getattr(self.loss_func, 'activation', noop)
#     240             res = cb.all_tensors()
#
# ~/.virtualenvs/cvpy/lib/python3.7/site-packages/fastai/learner.py in _do_epoch_validate(self, ds_idx, dl)
#     186         if dl is None: dl = self.dls[ds_idx]
#     187         self.dl = dl
# --> 188         with torch.no_grad(): self._with_events(self.all_batches, 'validate', CancelValidException)
#     189
#     190     def _do_epoch(self):
#
# ~/.virtualenvs/cvpy/lib/python3.7/site-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     153
#     154     def _with_events(self, f, event_type, ex, final=noop):
# --> 155         try:       self(f'before_{event_type}')       ;f()
#     156         except ex: self(f'after_cancel_{event_type}')
#     157         finally:   self(f'after_{event_type}')        ;final()
#
# ~/.virtualenvs/cvpy/lib/python3.7/site-packages/fastai/learner.py in all_batches(self)
#     159     def all_batches(self):
#     160         self.n_iter = len(self.dl)
# --> 161         for o in enumerate(self.dl): self.one_batch(*o)
#     162
#     163     def _do_one_batch(self):
#
# ~/.virtualenvs/cvpy/lib/python3.7/site-packages/fastai/data/load.py in __iter__(self)
#      99         self.before_iter()
#     100         self.__idxs=self.get_idxs() # called in context of main process (not workers/subprocesses)
# --> 101         for b in _loaders[self.fake_l.num_workers==0](self.fake_l):
#     102             if self.device is not None: b = to_device(b, self.device)
#     103             yield self.after_batch(b)
#
# ~/.virtualenvs/cvpy/lib/python3.7/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     433         if self._sampler_iter is None:
#     434             self._reset()
# --> 435         data = self._next_data()
#     436         self._num_yielded += 1
#     437         if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~/.virtualenvs/cvpy/lib/python3.7/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#     473     def _next_data(self):
#     474         index = self._next_index()  # may raise StopIteration
# --> 475         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     476         if self._pin_memory:
#     477             data = _utils.pin_memory.pin_memory(data)
#
# ~/.virtualenvs/cvpy/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      32                 raise StopIteration
#      33         else:
# ---> 34             data = next(self.dataset_iter)
#      35         return self.collate_fn(data)
#      36
#
# ~/.virtualenvs/cvpy/lib/python3.7/site-packages/fastai/data/load.py in create_batches(self, samps)
#     108         self.it = iter(self.dataset) if self.dataset is not None else None
#     109         res = filter(lambda o:o is not None, map(self.do_item, samps))
# --> 110         yield from map(self.do_batch, self.chunkify(res))
#     111
#     112     def new(self, dataset=None, cls=None, **kwargs):
#
# ~/.virtualenvs/cvpy/lib/python3.7/site-packages/fastcore/basics.py in chunked(it, chunk_sz, drop_last, n_chunks)
#     211     if not isinstance(it, Iterator): it = iter(it)
#     212     while True:
# --> 213         res = list(itertools.islice(it, chunk_sz))
#     214         if res and (len(res)==chunk_sz or not drop_last): yield res
#     215         if len(res)<chunk_sz: return
#
# ~/.virtualenvs/cvpy/lib/python3.7/site-packages/fastai/data/load.py in do_item(self, s)
#     123     def prebatched(self): return self.bs is None
#     124     def do_item(self, s):
# --> 125         try: return self.after_item(self.create_item(s))
#     126         except SkipItemException: return None
#     127     def chunkify(self, b): return b if self.prebatched else chunked(b, self.bs, self.drop_last)
#
# ~/.virtualenvs/cvpy/lib/python3.7/site-packages/fastai/data/load.py in create_item(self, s)
#     129     def randomize(self): self.rng = random.Random(self.rng.randint(0,2**32-1))
#     130     def retain(self, res, b):  return retain_types(res, b[0] if is_listy(b) else b)
# --> 131     def create_item(self, s):  return next(self.it) if s is None else self.dataset[s]
#     132     def create_batch(self, b): return (fa_collate,fa_convert)[self.prebatched](b)
#     133     def do_batch(self, b): return self.retain(self.create_batch(self.before_batch(b)), b)
#
# ~/.virtualenvs/cvpy/lib/python3.7/site-packages/fastai/data/core.py in __getitem__(self, it)
#     312
#     313     def __getitem__(self, it):
# --> 314         res = tuple([tl[it] for tl in self.tls])
#     315         return res if is_indexer(it) else list(zip(*res))
#     316
#
# ~/.virtualenvs/cvpy/lib/python3.7/site-packages/fastai/data/core.py in <listcomp>(.0)
#     312
#     313     def __getitem__(self, it):
# --> 314         res = tuple([tl[it] for tl in self.tls])
#     315         return res if is_indexer(it) else list(zip(*res))
#     316
#
# ~/.virtualenvs/cvpy/lib/python3.7/site-packages/fastai/data/core.py in __getitem__(self, idx)
#     278         res = super().__getitem__(idx)
#     279         if self._after_item is None: return res
# --> 280         return self._after_item(res) if is_indexer(idx) else res.map(self._after_item)
#     281
#     282 # Cell
#
# ~/.virtualenvs/cvpy/lib/python3.7/site-packages/fastai/data/core.py in _after_item(self, o)
#     240         return super()._new(items, tfms=self.tfms, do_setup=False, types=self.types, split_idx=split_idx, **kwargs)
#     241     def subset(self, i): return self._new(self._get(self.splits[i]), split_idx=i)
# --> 242     def _after_item(self, o): return self.tfms(o)
#     243     def __repr__(self): return f"{self.__class__.__name__}: {self.items}\ntfms - {self.tfms.fs}"
#     244     def __iter__(self): return (self[i] for i in range(len(self)))
#
# ~/.virtualenvs/cvpy/lib/python3.7/site-packages/fastcore/transform.py in __call__(self, o)
#     196         self.fs.append(t)
#     197
# --> 198     def __call__(self, o): return compose_tfms(o, tfms=self.fs, split_idx=self.split_idx)
#     199     def __repr__(self): return f"Pipeline: {' -> '.join([f.name for f in self.fs if f.name != 'noop'])}"
#     200     def __getitem__(self,i): return self.fs[i]
#
# ~/.virtualenvs/cvpy/lib/python3.7/site-packages/fastcore/transform.py in compose_tfms(x, tfms, is_enc, reverse, **kwargs)
#     148     for f in tfms:
#     149         if not is_enc: f = f.decode
# --> 150         x = f(x, **kwargs)
#     151     return x
#     152
#
# ~/.virtualenvs/cvpy/lib/python3.7/site-packages/fastcore/transform.py in __call__(self, x, **kwargs)
#      71     @property
#      72     def name(self): return getattr(self, '_name', _get_name(self))
# ---> 73     def __call__(self, x, **kwargs): return self._call('encodes', x, **kwargs)
#      74     def decode  (self, x, **kwargs): return self._call('decodes', x, **kwargs)
#      75     def __repr__(self): return f'{self.name}:\nencodes: {self.encodes}decodes: {self.decodes}'
#
# ~/.virtualenvs/cvpy/lib/python3.7/site-packages/fastcore/transform.py in _call(self, fn, x, split_idx, **kwargs)
#      81     def _call(self, fn, x, split_idx=None, **kwargs):
#      82         if split_idx!=self.split_idx and self.split_idx is not None: return x
# ---> 83         return self._do_call(getattr(self, fn), x, **kwargs)
#      84
#      85     def _do_call(self, f, x, **kwargs):
#
# ~/.virtualenvs/cvpy/lib/python3.7/site-packages/fastcore/transform.py in _do_call(self, f, x, **kwargs)
#      87             if f is None: return x
#      88             ret = f.returns_none(x) if hasattr(f,'returns_none') else None
# ---> 89             return retain_type(f(x, **kwargs), x, ret)
#      90         res = tuple(self._do_call(f, x_, **kwargs) for x_ in x)
#      91         return retain_type(res, x)
#
# ~/.virtualenvs/cvpy/lib/python3.7/site-packages/fastcore/dispatch.py in __call__(self, *args, **kwargs)
#     115         elif self.inst is not None: f = MethodType(f, self.inst)
#     116         elif self.owner is not None: f = MethodType(f, self.owner)
# --> 117         return f(*args, **kwargs)
#     118
#     119     def __get__(self, inst, owner):
#
# ~/.virtualenvs/cvpy/lib/python3.7/site-packages/fastai/vision/core.py in create(cls, fn, **kwargs)
#     108         if isinstance(fn,ndarray): return cls(Image.fromarray(fn))
#     109         if isinstance(fn,bytes): fn = io.BytesIO(fn)
# --> 110         return cls(load_image(fn, **merge(cls._open_args, kwargs)))
#     111
#     112     def show(self, ctx=None, **kwargs):
#
# ~/.virtualenvs/cvpy/lib/python3.7/site-packages/fastai/vision/core.py in load_image(fn, mode)
#      83 def load_image(fn, mode=None):
#      84     "Open and load a `PIL.Image` and convert to `mode`"
# ---> 85     im = Image.open(fn)
#      86     im.load()
#      87     im = im._new(im.im)
#
# ~/.virtualenvs/cvpy/lib/python3.7/site-packages/PIL/Image.py in open(fp, mode)
#    2876
#    2877     if filename:
# -> 2878         fp = builtins.open(filename, "rb")
#    2879         exclusive_fp = True
#    2880
#
# FileNotFoundError: [Errno 2] No such file or directory: 'fruits/banana/00000003.jpeg'

# %%
from PIL import Image
import torch
# example = Image.open('fruits/banana/00000003.jpeg')

# %%
model = torch.load('fruits.pkl')

# %%
img = open_image("../fruits/banana/00000000.jpg")
# Out:
# ----------------------------------------------------------------------
# NameError                            Traceback (most recent call last)
# <ipython-input-6-411b00ee6795> in <module>
# ----> 1 img = open_image("../fruits/banana/00000000.jpg")
#
# NameError: name 'open_image' is not defined

# %%
import keras

# %%
Image.open("../fruits/banana/00000000.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1600x1410 at 0x7F6B0E15D910>
